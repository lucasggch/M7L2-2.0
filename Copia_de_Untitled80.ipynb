# %%
# !pip install discord
# Out:
# Collecting discord
#   Downloading discord-2.3.2-py3-none-any.whl.metadata (381 bytes)
# Collecting discord.py>=2.3.2 (from discord)
#   Downloading discord_py-2.7.1-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: aiohttp<4,>=3.7.4 in /usr/local/lib/python3.13/dist-packages (from discord.py>=2.3.2->discord) (3.14.3)
# Requirement already satisfied: audioop-lts in /usr/local/lib/python3.13/dist-packages (from discord.py>=2.3.2->discord) (0.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.24.5)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.13/dist-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (3.19)
# Downloading discord-2.3.2-py3-none-any.whl (1.1 kB)
# Downloading discord_py-2.7.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.3 MB/s eta 0:00:00
# Installing collected packages: discord.py, discord
# Successfully installed discord-2.3.2 discord.py-2.7.1

# %%
# !unzip ./converted_keras.zip
# Out:
# Archive:  ./converted_keras.zip
#  extracting: keras_model.h5
#  extracting: labels.txt

# %%
# importamos la libreria PIL: Python Imaging Library
# es necesario para poder abrir la imagen a analizar
import PIL
from PIL import Image, ImageOps
import numpy as np
# Instalamos keras, libreria necesaria para que funcionen
# las redes neuronales
# !pip install -q tf-keras==2.19.0 h5py==3.11.0
# Importando tf-keras – una versión de Keras compatible con modelos .h5
import tf_keras as keras
# Importando la función load_model de tf_keras, que nos
# permitira cargar el modelo de google teachable machine
from tf_keras.models import load_model
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 406.5/406.5 kB 19.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ERROR: Could not find a version that satisfies the requirement tensorflow<2.20,>=2.19 (from tf-keras) (from versions: 2.20.0rc0, 2.20.0, 2.21.0rc0, 2.21.0rc1, 2.21.0)
# ERROR: No matching distribution found for tensorflow<2.20,>=2.19

# %%
import discord
from discord.ext import commands
import nest_asyncio

nest_asyncio.apply()

# %%
model_path = "./keras_model.h5"
labels_path = "./labels.txt"

def get_class(image_path):
  np.set_printoptions(suppress=True)
  model = load_model(model_path, compile=False)
  class_names = open(labels_path, "r").readlines()
  data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
  image = Image.open(image_path).convert("RGB")
  size = (224, 224)
  image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)
  image_array = np.asarray(image)
  normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1
  data[0] = normalized_image_array
  prediction = model.predict(data)
  print(prediction)
  index = np.argmax(prediction)
  class_name = class_names[index]
  confidence_score = prediction[0][index]
  text1 = f"Clase: {class_name[2:]} Probabilidad: {confidence_score}"
  return text1

# %%
#Definimos los permisos del bot
intents = discord.Intents.default()
intents.message_content = True
#creamos el bot
bot = commands.Bot(command_prefix='$', intents=intents)

@bot.event
async def on_ready():
    print(f'Inicie cesion como {bot.user}')
#este comando saluda al usuario
#para activarlo se escribe $hello
@bot.command()
async def hello(ctx):
    await ctx.send(f'Hola! soy el {bot.user}!')

#escribe tu codigo aqui
@bot.command()
async def check(ctx):
  if ctx.message.attachments:
    for archivo in ctx.message.attachments:
      file_name = archivo.filename
      file_url = archivo.url
      await archivo.save(f"./{file_name}")
      await ctx.send("Imagen guardada con exito.")
      respuesta = get_class(f"./{file_name}")
      await ctx.send(respuesta)
  else:
    await ctx.send("No has enviado ninguna imagen")


bot.run("MTU0MDE0NDE2OTc5ODk5NTk4OA.GqBELJ.AEX5I8xKCugsMndBacK_QbCFWnML-nVnGHPtmg")
# Out:
# 2026-08-27 23:53:28 INFO     discord.client logging in using static token
# 2026-08-27 23:53:28 INFO     discord.client logging in using static token
# 2026-08-27 23:53:28 INFO     discord.client logging in using static token
# 2026-08-27 23:53:28 INFO     discord.client logging in using static token
# INFO:discord.client:logging in using static token
# 2026-08-27 23:53:29 INFO     discord.gateway Shard ID None has connected to Gateway (Session ID: d00ec4e29a4dd99aea83ea63d6153653).
# 2026-08-27 23:53:29 INFO     discord.gateway Shard ID None has connected to Gateway (Session ID: d00ec4e29a4dd99aea83ea63d6153653).
# 2026-08-27 23:53:29 INFO     discord.gateway Shard ID None has connected to Gateway (Session ID: d00ec4e29a4dd99aea83ea63d6153653).
# 2026-08-27 23:53:29 INFO     discord.gateway Shard ID None has connected to Gateway (Session ID: d00ec4e29a4dd99aea83ea63d6153653).
# INFO:discord.gateway:Shard ID None has connected to Gateway (Session ID: d00ec4e29a4dd99aea83ea63d6153653).
# Inicie cesion como bot para clase de python#5494
# 1/1 [==============================] - 1s 1s/step
# [[0.99987006 0.00012997]]
